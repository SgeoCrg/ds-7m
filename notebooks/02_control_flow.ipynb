# %%
num = [-1, 0, 1]
personas_edad = {
    "Pedro": 11,
    "Maria": 16,
    "Lorenzo": 18,
    "Antonio": 25
}

ventas = [10, 25, 7, 30]

numeros = [0, 42, 7, 89, 15, 63, 28, 91, 34, 56, 3, 77, 20, 68]

palabras = ['casa', 'perro', 'sol', 'libro', 'agua', 'árbol', 'cielo', 'montaña', 'río', 'flor']

catalogo_tienda = {
    "Camiseta básica": 12.99,
    "Camiseta premium": 19.99,
    "Zapatillas deportivas": 89.99,
    "Zapatillas casual": 59.99,
    "Pantalón vaquero": 39.99,
    "Pantalón chándal": 29.99,
    "Sudadera": 45.00,
    "Chaqueta ligera": 69.99,
    "Chaqueta invierno": 129.99,
    "Gorra": 12.50,
    "Calcetines (pack 3)": 8.99,
    "Chándal completo": 79.99
}
usuarios = {
    'alex': '1234'
}

notas_examen = [
    {"alumno": "Ana García", "nota": 8.5},
    {"alumno": "Carlos López", "nota": 6.2},
    {"alumno": "María Pérez", "nota": 9.1},
    {"alumno": "David Ruiz", "nota": 4.8},
    {"alumno": "Lucía Martínez", "nota": 7.9},
    {"alumno": "Pedro Sánchez", "nota": 5.5},
    {"alumno": "Sofía Rodríguez", "nota": 8.7},
    {"alumno": "Miguel Torres", "nota": 6.8},
    {"alumno": "Elena Díaz", "nota": 9.3},
    {"alumno": "Javier Morales", "nota": 7.2},
    {"alumno": "Carmen Vega", "nota": 5.9},
    {"alumno": "Raúl Castro", "nota": 8.0},
    {"alumno": "Paula Navarro", "nota": 6.5},
    {"alumno": "Diego Silva", "nota": 7.6},
    {"alumno": "Sara Jiménez", "nota": 9.0}
]

def crear_lista_cuadrados(cantidad_numeros):
    cuadrados = []
    for i in range(cantidad_numeros):
        cuadrados.append(i+1)
    cuadrados = [n**2 for n in cuadrados]
    return cuadrados

def imprimir_catalogo(catalogo):
    for clave, valor in catalogo.items():
        print(f"{clave} -> {valor:.2f}")

def login(usuarios):
    correcto = False
    incorrecto = ""
    while not correcto:
        user_log = input(f"{incorrecto}\nUsuario: ")
        password = input("Password: ")
        for clave in usuarios:
            incorrecto = "Usuario o contraseña incorrectas"
            if user_log in usuarios and password == usuarios[clave]:
                print(f"Welcome {user_log}")
                correcto = True

def calcular_aprobados(lista):
    aprobados = [linea for linea in lista if linea['nota'] > 5]
    return aprobados

for i in num:
    if i == 0:
        print(f"{i} es 0")
    elif i > 0:
        print(f"{i} es positivo")
    else:
        print(f"{i} es negativo")

for persona in personas_edad:
    if personas_edad[persona] < 12:
        print(f"{persona} es niño")
    elif personas_edad[persona] >= 12 and personas_edad[persona] < 18:
        print(f"{persona} es adolescente")
    else:
        print(f"{persona} es adulto")

palabras_cortas = [palabra for palabra in palabras if len(palabra) > 4]

print(f"total_ventas: {sum(ventas)}")

pares = [n for n in numeros if n%2 == 0]
print(f"pares: {len(pares)}, impares: {len(numeros) - len(pares)}")
print(crear_lista_cuadrados(20))

print(f"{palabras_cortas}")
imprimir_catalogo(catalogo_tienda)
#login(usuarios)
print(f"aprobados: {len(calcular_aprobados(notas_examen))} de {len(notas_examen)}")

catalogo_tienda_iva = {producto: precio * 1.21 for producto, precio in catalogo_tienda.items()}
print(catalogo_tienda_iva)
imprimir_catalogo(catalogo_tienda_iva)
# Out:
# -1 es negativo
# 0 es 0
# 1 es positivo
# Pedro es niño
# Maria es adolescente
# Lorenzo es adulto
# Antonio es adulto
# total_ventas: 72
# pares: 7, impares: 7
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400]
# ['perro', 'libro', 'árbol', 'cielo', 'montaña']
# Camiseta básica -> 12.99
# Camiseta premium -> 19.99
# Zapatillas deportivas -> 89.99
# Zapatillas casual -> 59.99
# Pantalón vaquero -> 39.99
# Pantalón chándal -> 29.99
# Sudadera -> 45.00
# Chaqueta ligera -> 69.99
# Chaqueta invierno -> 129.99
# Gorra -> 12.50
# Calcetines (pack 3) -> 8.99
# Chándal completo -> 79.99
# aprobados: 14 de 15
# ...
